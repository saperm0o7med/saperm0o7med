# %%
#Fianl_project_UK-Accident2018 4 NTI
#BY Saper Mohamed
#15/2/2026

# %%
#importing lib needed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#loading Data
df1=pd.read_csv('Accidents_2018.csv')
df2=pd.read_csv('Casualties_2018.csv')
df3=pd.read_csv('Vehicles_2018.csv')
# Out:
# /tmp/ipykernel_2415/3849240815.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('Accidents_2018.csv')
# /tmp/ipykernel_2415/3849240815.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3=pd.read_csv('Vehicles_2018.csv')

# %%
#check data shape
print('Accidents_2018 data shape is :' , df1.shape)
print('Casualties_2018 data shape is :' ,df2.shape)
print('Vehicles_2018 data shape is :' ,df3.shape)
# Out:
# Accidents_2018 data shape is : (122635, 32)
# Casualties_2018 data shape is : (160597, 16)
# Vehicles_2018 data shape is : (226409, 23)

# %%
#check data for df1
df1.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  2018010080971               529150.0                182270.0  -0.139737
# 1  2018010080973               542020.0                184290.0   0.046471
# 2  2018010080974               531720.0                182910.0  -0.102474
# 3  2018010080981               541450.0                183220.0   0.037828
# 4  2018010080982               543580.0                176500.0   0.065781
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.524587             1                  3                   2
# 1  51.539651             1                  3                   1
# 2  51.529746             1                  3                   2
# 3  51.530179             1                  2                   2
# 4  51.469258             1                  2                   2
#
#    Number_of_Casualties        Date  ...  Pedestrian_Crossing-Human_Control  \
# ...

# %%
#check data for df2
df2.head()
# Out:
#   Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0  2018010080971                  1                   1               2
# 1  2018010080971                  2                   2               1
# 2  2018010080973                  1                   1               3
# 3  2018010080974                  1                   1               1
# 4  2018010080981                  1                   1               1
#
#    Sex_of_Casualty  Age_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 0                2               50                     8                  3
# 1                1               48                     8                  3
# 2                1               29                     6                  3
# 3                1               40                     7                  3
# 4                1               27                     6                  2
#
#    Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# ...

# %%
#check data for df3
df3.head()
# Out:
#   Accident_Index  Vehicle_Reference  Vehicle_Type  Towing_and_Articulation  \
# 0  2018010080971                  1             9                        0
# 1  2018010080971                  2             8                        0
# 2  2018010080973                  1             9                        0
# 3  2018010080974                  1             8                        0
# 4  2018010080974                  2             9                        0
#
#    Vehicle_Manoeuvre  Vehicle_Location-Restricted_Lane  Junction_Location  \
# 0                 18                                 0                  0
# 1                 18                                 0                  0
# 2                 18                                 0                  2
# 3                  7                                 0                  8
# 4                 18                                 0                  1
#
#    Skidding_and_Overturning  Hit_Object_in_Carriageway  \
# ...

# %%
#merging all dataset together (merging df1 and df2)
dataFrame=pd.merge(df1,df2,on='Accident_Index')

# %%
#check data shape after merging
dataFrame.shape
# Out:
# (140958, 47)

# %%
#check data
dataFrame.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  2018010130027               523810.0                185730.0  -0.215455
# 1  2018010130028               517980.0                185050.0  -0.299739
# 2  2018010130028               517980.0                185050.0  -0.299739
# 3  2018010130030               542820.0                182610.0   0.057318
# 4  2018010130030               542820.0                182610.0   0.057318
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.556878             1                  3                   2
# 1  51.552014             1                  3                   1
# 2  51.552014             1                  3                   1
# 3  51.524353             1                  3                   2
# 4  51.524353             1                  3                   2
#
#    Number_of_Casualties        Date  ...  Age_Band_of_Casualty  \
# ...

# %%
#merge 3rd data frame with our data
df=pd.merge(dataFrame,df3,on='Accident_Index')

# %%
#checking final data size
df.shape
# Out:
# (270941, 69)

# %%
df.head(15)
# Out:
#    Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0   2018010135259               534140.0                168370.0  -0.073120
# 1   2018010135259               534140.0                168370.0  -0.073120
# 2   2018010135261               535780.0                185300.0  -0.043058
# 3   2018010135264               534120.0                192440.0  -0.064263
# 4   2018010135268               529080.0                162590.0  -0.147913
# 5   2018010135268               529080.0                162590.0  -0.147913
# 6   2018010135268               529080.0                162590.0  -0.147913
# 7   2018010135268               529080.0                162590.0  -0.147913
# 8   2018010135270               533970.0                196400.0  -0.064912
# 9   2018010135270               533970.0                196400.0  -0.064912
# 10  2018010135273               528850.0                179160.0  -0.145195
# ...

# %%
df.describe()
# Out:
#        Location_Easting_OSGR  Location_Northing_OSGR      Longitude  \
# count          270821.000000            2.708210e+05  270821.000000
# mean           438054.364654            2.994161e+05      -1.457019
# std             96838.617305            1.571379e+05       1.421335
# min             84654.000000            1.023500e+04      -7.266148
# 25%            373489.000000            1.757210e+05      -2.399441
# 50%            436827.000000            2.812210e+05      -1.449127
# 75%            515249.000000            3.987760e+05      -0.325279
# max            655275.000000            1.209512e+06       1.758123
#
#             Latitude   Police_Force  Accident_Severity  Number_of_Vehicles  \
# count  270821.000000  270941.000000      270941.000000       270941.000000
# mean       52.582586      33.313105           2.758678            2.290916
# std         1.415271      23.464854           0.471688            1.158296
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270941 entries, 0 to 270940
# Data columns (total 69 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Accident_Index                               270941 non-null  object
#  1   Location_Easting_OSGR                        270821 non-null  float64
#  2   Location_Northing_OSGR                       270821 non-null  float64
#  3   Longitude                                    270821 non-null  float64
#  4   Latitude                                     270821 non-null  float64
#  5   Police_Force                                 270941 non-null  int64
#  6   Accident_Severity                            270941 non-null  int64
#  7   Number_of_Vehicles                           270941 non-null  int64
#  8   Number_of_Casualties                         270941 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
#        'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
#        'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
#        'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location', 'Vehicle_Reference_x',
#        'Casualty_Reference', 'Casualty_Class', 'Sex_of_Casualty',
#        'Age_of_Casualty', 'Age_Band_of_Casualty', 'Casualty_Severity',
# ...

# %%
df
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       2018010135259               534140.0                168370.0
# 1       2018010135259               534140.0                168370.0
# 2       2018010135261               535780.0                185300.0
# 3       2018010135264               534120.0                192440.0
# 4       2018010135268               529080.0                162590.0
# ...               ...                    ...                     ...
# 270936  2018984116018               319337.0                574511.0
# 270937  2018984116018               319337.0                574511.0
# 270938  2018984116018               319337.0                574511.0
# 270939  2018984116318               318858.0                566932.0
# 270940  2018984116418               316008.0                568771.0
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.073120  51.398512             1                  3
# ...

# %%
df.value_counts('Accident_Severity')
# Out:
# Accident_Severity
# 3    210895
# 2     54708
# 1      5338
# Name: count, dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# LSOA_of_Accident_Location    15762
# Longitude                      120
# Location_Northing_OSGR         120
# Latitude                       120
# Location_Easting_OSGR          120
#                              ...
# Propulsion_Code                  0
# Age_of_Vehicle                   0
# Driver_IMD_Decile                0
# Driver_Home_Area_Type            0
# Vehicle_IMD_Decile               0
# Length: 69, dtype: int64

# %%
df
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       2018010135259               534140.0                168370.0
# 1       2018010135259               534140.0                168370.0
# 2       2018010135261               535780.0                185300.0
# 3       2018010135264               534120.0                192440.0
# 4       2018010135268               529080.0                162590.0
# ...               ...                    ...                     ...
# 270936  2018984116018               319337.0                574511.0
# 270937  2018984116018               319337.0                574511.0
# 270938  2018984116018               319337.0                574511.0
# 270939  2018984116318               318858.0                566932.0
# 270940  2018984116418               316008.0                568771.0
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.073120  51.398512             1                  3
# ...

# %%
df.value_counts('Age_Band_of_Driver')
# Out:
# Age_Band_of_Driver
#  6     57547
#  7     45570
#  8     42292
# -1     27461
#  5     27202
#  9     26674
#  4     18841
#  10    14258
#  11     8968
#  3      1675
#  2       412
#  1        41
# Name: count, dtype: int64

# %%
df.value_counts('Age_of_Vehicle')
# Out:
# Age_of_Vehicle
# -1     63701
#  1     17237
#  2     16704
#  3     16090
#  4     15101
#        ...
#  57        1
#  67        1
#  77        1
#  83        1
#  84        1
# Name: count, Length: 70, dtype: int64

# %%
df.replace([-1, '-1'], np.nan, inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Junction_Control             126226
# 2nd_Road_Class               124059
# Driver_IMD_Decile             65868
# Vehicle_IMD_Decile            65868
# Age_of_Vehicle                63701
#                               ...
# Local_Authority_(Highway)         0
# Road_Type                         0
# Vehicle_Reference_y               0
# Pedestrian_Movement               0
# Casualty_Severity                 0
# Length: 69, dtype: int64

# %%
df.drop(['Junction_Control','2nd_Road_Class'],axis=1,inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Driver_IMD_Decile             65868
# Vehicle_IMD_Decile            65868
# Age_of_Vehicle                63701
# Engine_Capacity_(CC)          53932
# Propulsion_Code               53401
#                               ...
# Local_Authority_(District)        0
# 1st_Road_Class                    0
# Vehicle_Reference_y               0
# Pedestrian_Movement               0
# Casualty_Severity                 0
# Length: 67, dtype: int64

# %%
df
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       2018010135259               534140.0                168370.0
# 1       2018010135259               534140.0                168370.0
# 2       2018010135261               535780.0                185300.0
# 3       2018010135264               534120.0                192440.0
# 4       2018010135268               529080.0                162590.0
# ...               ...                    ...                     ...
# 270936  2018984116018               319337.0                574511.0
# 270937  2018984116018               319337.0                574511.0
# 270938  2018984116018               319337.0                574511.0
# 270939  2018984116318               318858.0                566932.0
# 270940  2018984116418               316008.0                568771.0
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.073120  51.398512             1                  3
# ...

# %%
df.drop('Casualty_Severity',axis=1,inplace=True)

# %%
df.drop ('Accident_Index',axis=1,inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Driver_IMD_Decile            65868
# Vehicle_IMD_Decile           65868
# Age_of_Vehicle               63701
# Engine_Capacity_(CC)         53932
# Propulsion_Code              53401
#                              ...
# Local_Authority_(Highway)        0
# 1st_Road_Class                   0
# 1st_Road_Number                  0
# Vehicle_Reference_y              0
# Pedestrian_Movement              0
# Length: 65, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(6)

# %%
df.drop_duplicates(inplace=True)

# %%
from sklearn.impute import SimpleImputer
impute = SimpleImputer(missing_values=np.nan,strategy='median')

# %%
cols_median=['Age_of_Casualty','Age_of_Driver','Engine_Capacity_(CC)','Age_of_Vehicle']

# %%
impute.fit(df[cols_median])
# Out:
# SimpleImputer(strategy='median')

# %%
df[cols_median] = impute.transform(df[cols_median])

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Driver_IMD_Decile        65867
# Vehicle_IMD_Decile       65867
# Propulsion_Code          53398
# Casualty_IMD_Decile      48648
# Driver_Home_Area_Type    46215
#                          ...
# Age_of_Casualty              0
# Vehicle_Reference_y          0
# Age_of_Driver                0
# Engine_Capacity_(CC)         0
# Age_of_Vehicle               0
# Length: 65, dtype: int64

# %%
cols_mode = ['Driver_IMD_Decile', 'Vehicle_IMD_Decile', 'Propulsion_Code', 'Casualty_IMD_Decile', 'Driver_Home_Area_Type', 'LSOA_of_Accident_Location', 'Age_Band_of_Driver', 'Age_Band_of_Casualty', 'Time', 'Sex_of_Driver', 'Sex_of_Casualty', 'Casualty_Home_Area_Type', 'Urban_or_Rural_Area', 'Junction_Detail', 'Car_Passenger', 'Road_Type', 'Towing_and_Articulation', 'Vehicle_Type', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Skidding_and_Overturning', 'Hit_Object_in_Carriageway', 'Vehicle_Manoeuvre', 'Vehicle_Leaving_Carriageway', 'Vehicle_Location-Restricted_Lane', 'Hit_Object_off_Carriageway', '1st_Point_of_Impact', 'Was_Vehicle_Left_Hand_Drive?', 'Junction_Location', 'Pedestrian_Crossing-Human_Control', 'Pedestrian_Crossing-Physical_Facilities', 'Road_Surface_Conditions', 'Special_Conditions_at_Site', 'Carriageway_Hazards', 'Light_Conditions', '2nd_Road_Number', 'Bus_or_Coach_Passenger', 'Pedestrian_Road_Maintenance_Worker', 'Weather_Conditions', 'Journey_Purpose_of_Driver']

# %%
impute_mode = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

for i in cols_mode:
    if i in df.columns:
        df[i] = impute_mode.fit_transform(df[[i]]).ravel()

# %%
df.dropna(subset=['Did_Police_Officer_Attend_Scene_of_Accident','Pedestrian_Location','Casualty_Type','2nd_Road_Number', 'Bus_or_Coach_Passenger', 'Pedestrian_Road_Maintenance_Worker', 'Weather_Conditions', 'Journey_Purpose_of_Driver'], inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Location_Easting_OSGR     0
# Location_Northing_OSGR    0
# Longitude                 0
# Latitude                  0
# Police_Force              0
#                          ..
# Propulsion_Code           0
# Age_of_Vehicle            0
# Driver_IMD_Decile         0
# Driver_Home_Area_Type     0
# Vehicle_IMD_Decile        0
# Length: 65, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 270912 entries, 0 to 270940
# Data columns (total 65 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Location_Easting_OSGR                        270912 non-null  float64
#  1   Location_Northing_OSGR                       270912 non-null  float64
#  2   Longitude                                    270912 non-null  float64
#  3   Latitude                                     270912 non-null  float64
#  4   Police_Force                                 270912 non-null  int64
#  5   Accident_Severity                            270912 non-null  int64
#  6   Number_of_Vehicles                           270912 non-null  int64
#  7   Number_of_Casualties                         270912 non-null  int64
#  8   Date                                         270912 non-null  object
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['Year'] = df['Date'].dt.year

df['Hour'] = pd.to_datetime(df['Time'], format='%H:%M').dt.hour
df = df.drop(columns=['Date', 'Time'])

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Location_Easting_OSGR     0
# Location_Northing_OSGR    0
# Longitude                 0
# Latitude                  0
# Police_Force              0
#                          ..
# Vehicle_IMD_Decile        0
# Month                     0
# Day                       0
# Year                      0
# Hour                      0
# Length: 67, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 270912 entries, 0 to 270940
# Data columns (total 67 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Location_Easting_OSGR                        270912 non-null  float64
#  1   Location_Northing_OSGR                       270912 non-null  float64
#  2   Longitude                                    270912 non-null  float64
#  3   Latitude                                     270912 non-null  float64
#  4   Police_Force                                 270912 non-null  int64
#  5   Accident_Severity                            270912 non-null  int64
#  6   Number_of_Vehicles                           270912 non-null  int64
#  7   Number_of_Casualties                         270912 non-null  int64
#  8   Day_of_Week                                  270912 non-null  int64
# ...

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y)
plt.title('Scatter Plot')
plt.show()

# %%
lsoa_stats = df.groupby('LSOA_of_Accident_Location').agg({'Accident_Severity': ['count', 'mean']})
lsoa_stats.columns = ['Accident_Count', 'Mean_Severity']

# %%
lsoa_stats = df.groupby('LSOA_of_Accident_Location').agg({'Accident_Severity': ['count', 'mean']})
lsoa_stats.columns = ['Accident_Count', 'Mean_Severity']

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=lsoa_stats, x='Accident_Count', y='Mean_Severity', alpha=0.5, color='red')
plt.title('Relationship between Accident Frequency and Severity per LSOA')
plt.xlabel('Number of Accidents in Area')
plt.ylabel('Average Severity (1=Fatal, 3=Slight)')
plt.show()

# %%
df.value_counts('LSOA_of_Accident_Location')
# Out:
# LSOA_of_Accident_Location
# E01032739    16049
# E01018648      242
# E01030458      236
# E01021800      193
# E01024335      193
#              ...
# E01005369        1
# E01005363        1
# E01024702        1
# E01005331        1
# E01000058        1
# Name: count, Length: 26595, dtype: int64

# %%
outlier_code = 'E01032739'
print(f"Severity distribution for {outlier_code}:")
print(df[df['LSOA_of_Accident_Location'] == outlier_code]['Accident_Severity'].value_counts(normalize=True))
# Out:
# Severity distribution for E01032739:
# Accident_Severity
# 3    0.741292
# 2    0.228924
# 1    0.029784
# Name: proportion, dtype: float64

# %%
pivot = df.pivot_table(index='Light_Conditions', columns='Weather_Conditions',
                       values='Accident_Severity', aggfunc='mean')
plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, cmap='RdYlGn', fmt=".2f")
plt.title('Heatmap: Average Severity by Weather and Light')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Road_Type', hue='Accident_Severity', data=df)
plt.title('Accident Severity Counts by Road Type')
plt.xticks(rotation=45)
plt.legend(title='Severity (1=Fatal, 2=Serious, 3=Slight)')
plt.show()

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Location_Easting_OSGR     0
# Location_Northing_OSGR    0
# Longitude                 0
# Latitude                  0
# Police_Force              0
#                          ..
# Vehicle_IMD_Decile        0
# Month                     0
# Day                       0
# Year                      0
# Hour                      0
# Length: 67, dtype: int64

# %%
# !pip install category-encoders

# %%
from category_encoders import TargetEncoder

encoder = TargetEncoder(cols=['LSOA_of_Accident_Location', 'Local_Authority_(Highway)'])

df[['LSOA_of_Accident_Location', 'Local_Authority_(Highway)']] = encoder.fit_transform(df[['LSOA_of_Accident_Location', 'Local_Authority_(Highway)']], df['Accident_Severity'])


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 270912 entries, 0 to 270940
# Data columns (total 67 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Location_Easting_OSGR                        270912 non-null  float64
#  1   Location_Northing_OSGR                       270912 non-null  float64
#  2   Longitude                                    270912 non-null  float64
#  3   Latitude                                     270912 non-null  float64
#  4   Police_Force                                 270912 non-null  int64
#  5   Accident_Severity                            270912 non-null  int64
#  6   Number_of_Vehicles                           270912 non-null  int64
#  7   Number_of_Casualties                         270912 non-null  int64
#  8   Day_of_Week                                  270912 non-null  int64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    balanced_accuracy_score,
    roc_auc_score,roc_curve,
    precision_recall_curve,average_precision_score
)
# Classification models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.naive_bayes import GaussianNB

from sklearn.ensemble import (
    RandomForestClassifier,
    ExtraTreesClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier,
    VotingClassifier,
    StackingClassifier
)

from xgboost import XGBClassifier
# from catboost import CatBoostClassifier # Commented out due to ModuleNotFoundError
from lightgbm import LGBMClassifier

# Install catboost if not already installed
try:
    from catboost import CatBoostClassifier
except ImportError:
    # %pip install catboost
    from catboost import CatBoostClassifier

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Accident_Severity', axis=1)
y = df['Accident_Severity'] - 1 # Subtract 1 to make labels 0-indexed

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                   test_size=0.20, random_state=100, stratify=y)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Location_Easting_OSGR     0
# Location_Northing_OSGR    0
# Longitude                 0
# Latitude                  0
# Police_Force              0
#                          ..
# Vehicle_IMD_Decile        0
# Month                     0
# Day                       0
# Year                      0
# Hour                      0
# Length: 67, dtype: int64

# %%
from category_encoders import TargetEncoder

# %%
encoder = TargetEncoder(cols=['LSOA_of_Accident_Location', 'Local_Authority_(Highway)'])

X_train = encoder.fit_transform(X_train, y_train)
X_test = encoder.transform(X_test)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 270912 entries, 0 to 270940
# Data columns (total 67 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Location_Easting_OSGR                        270912 non-null  float64
#  1   Location_Northing_OSGR                       270912 non-null  float64
#  2   Longitude                                    270912 non-null  float64
#  3   Latitude                                     270912 non-null  float64
#  4   Police_Force                                 270912 non-null  int64
#  5   Accident_Severity                            270912 non-null  int64
#  6   Number_of_Vehicles                           270912 non-null  int64
#  7   Number_of_Casualties                         270912 non-null  int64
#  8   Day_of_Week                                  270912 non-null  int64
# ...

# %%
# MinMaxScaler
my_scaler = MinMaxScaler()
X_train = my_scaler.fit_transform(X_train)
X_test = my_scaler.transform(X_test)

# %%
sample_size = int(0.2* X_train.shape[0])
random_indices = np.random.choice(X_train.shape[0], size=sample_size, replace=False)
X_train_sample = X_train[random_indices]
y_train_sample = y_train.iloc[random_indices] if isinstance(y_train, pd.Series) else y_train[random_indices]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import (
    RandomForestClassifier,
    ExtraTreesClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier,
    VotingClassifier,
    StackingClassifier
)
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

# %%
models = {

    # Logistic
    "Logistic Regression": LogisticRegression(max_iter=2000, random_state=1),

    # Distance-based
    "KNN": KNeighborsClassifier(n_neighbors=5),

    # SVM
    "SVC": SVC(probability=True, random_state=1),

    # Tree
    "Decision Tree": DecisionTreeClassifier(random_state=1),

    # Naive Bayes
    "Naive Bayes": GaussianNB(),

    # Bagging Based
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=1),
    "Extra Trees": ExtraTreesClassifier(n_estimators=100, random_state=1),

    # Boosting
    "AdaBoost": AdaBoostClassifier(random_state=1),
    "Gradient Boosting": GradientBoostingClassifier(random_state=1),
    "Hist Gradient Boosting": HistGradientBoostingClassifier(random_state=1),

    # External Boosting Libraries
    "XGBoost": XGBClassifier(eval_metric='logloss', random_state=1, use_label_encoder=False),
    "CatBoost": CatBoostClassifier(verbose=0, random_state=1),
    "LightGBM": LGBMClassifier(random_state=1)
}

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Location_Easting_OSGR     0
# Location_Northing_OSGR    0
# Longitude                 0
# Latitude                  0
# Police_Force              0
#                          ..
# Vehicle_IMD_Decile        0
# Month                     0
# Day                       0
# Year                      0
# Hour                      0
# Length: 67, dtype: int64

# %%
from tqdm import tqdm

results = {}

for name, model in tqdm(models.items()):
    model.fit(X_train_sample,y_train_sample)

    train_pred = model.predict(X_train_sample)
    test_pred  = model.predict(X_test)

    results[name] = {
        "Train Accuracy": accuracy_score(y_train_sample, train_pred),
        "Test Accuracy": accuracy_score(y_test, test_pred),
        "Train Precision": precision_score(y_train_sample, train_pred, average='weighted'),
        "Test Precision": precision_score(y_test, test_pred, average='weighted'),
        "Train Recall": recall_score(y_train_sample, train_pred, average='weighted'),
        "Test Recall": recall_score(y_test, test_pred, average='weighted'),
        "Train F1 Score": f1_score(y_train_sample, train_pred, average='weighted'),
        "Test F1 Score": f1_score(y_test, test_pred, average='weighted'),
        "Train Balanced Accuracy": balanced_accuracy_score(y_train_sample, train_pred),
        "Test Balanced Accuracy": balanced_accuracy_score(y_test, test_pred)

    }
# Out:
#  77%|███████▋  | 10/13 [12:38<01:55, 38.48s/it]/usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [18:31:46] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  92%|█████████▏| 12/13 [13:26<00:32, 33.00s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019952 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3217
# [LightGBM] [Info] Number of data points in the train set: 43345, number of used features: 65
# [LightGBM] [Info] Start training from score -3.916532
# [LightGBM] [Info] Start training from score -1.589565
# [LightGBM] [Info] Start training from score -0.253505
# ...

# %%
results_df = pd.DataFrame(results).T
results_df = results_df.sort_values(by="Test F1 Score", ascending=False)

# %%
results_df
# Out:
#                         Train Accuracy  Test Accuracy  Train Precision  \
# XGBoost                       0.937202       0.863758         0.936638
# Random Forest                 1.000000       0.869000         1.000000
# CatBoost                      0.916023       0.861451         0.914456
# Hist Gradient Boosting        0.916253       0.860362         0.914358
# LightGBM                      0.897889       0.858793         0.894649
# Gradient Boosting             0.857238       0.850377         0.849549
# Extra Trees                   1.000000       0.856597         1.000000
# Decision Tree                 1.000000       0.829541         1.000000
# AdaBoost                      0.828908       0.828470         0.822445
# SVC                           0.842335       0.830334         0.833582
# Logistic Regression           0.828331       0.824927         0.812723
# KNN                           0.841919       0.780245         0.830168
# ...

# %%
results_df[["Test Accuracy", "Train Accuracy"]].plot.bar(figsize=(12,6))
# Out:
# <Axes: >

# %%
cols = [
    ['Train Accuracy', 'Test Accuracy'],
    ['Train Precision', 'Test Precision'],
    ['Train Recall', 'Test Recall'],
    ['Train F1 Score', 'Test F1 Score'],
    ["Train Balanced Accuracy", "Test Balanced Accuracy"]
]

plt.figure(figsize=(30,30))

for i, col in enumerate(cols):
    ax = plt.subplot(3, 2, i+1)
    results_df[col].plot.bar(ax=ax)
    ax.set_title(col[0].split(" ")[1] + ' Comparison')

plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
model_params = {
    'GradientBoosting': {
        'model': GradientBoostingClassifier(random_state=42),
        'params': {
            'n_estimators': [100, 150],
            'learning_rate': [0.1],
            'max_depth': [3, 5]
        }
    },
    'XGBoost': {
        'model': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
        'params': {
            'n_estimators': [100, 150],
            'max_depth': [3, 6],
            'learning_rate': [0.1]
        }
    },
    'CatBoost': {
        'model': CatBoostClassifier(silent=True, random_state=42),
        'params': {
            'iterations': [100, 200],
            'depth': [4, 6],
            'learning_rate': [0.1]
        }
    }
}

# %%
scores = []

print("Starting Grid Search... This might take some time since you increased data to 20%")

for model_name, mp in model_params.items():

    clf = GridSearchCV(mp['model'], mp['params'], cv=3, return_train_score=False, n_jobs=-1)
    clf.fit(X_train_sample, y_train_sample)

    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    print(f"Finished {model_name}")
# Out:
# Starting Grid Search... This might take some time since you increased data to 20%
# Finished GradientBoosting
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [18:50:00] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Finished XGBoost
# Finished CatBoost

# %%
import pandas as pd
tuning_results = pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
display(tuning_results)
# Out:
#               model  best_score  \
# 0  GradientBoosting    0.856246
# 1           XGBoost    0.855947
# 2          CatBoost    0.851632
#
#                                          best_params
# 0  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 1  {'learning_rate': 0.1, 'max_depth': 6, 'n_esti...
# 2  {'depth': 6, 'iterations': 200, 'learning_rate...

# %%
import xgboost as xgb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

b_model = xgb.XGBClassifier(
    learning_rate=0.1,
    max_depth=6,
    n_estimators=150,
    random_state=42
)
b_model.fit(X_train, y_train)

importances = b_model.feature_importances_
feature_names = X.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

display(feature_importance_df.head(15))

plt.figure(figsize=(10, 8))
plt.barh(feature_importance_df['Feature'].head(15), feature_importance_df['Importance'].head(15))
plt.gca().invert_yaxis()
plt.title('Top 15 Features for Accident Severity Prediction')
plt.show()
# Out:
#                                         Feature  Importance
# 25                    LSOA_of_Accident_Location    0.229089
# 37                                Casualty_Type    0.059043
# 24  Did_Police_Officer_Attend_Scene_of_Accident    0.049850
# 6                          Number_of_Casualties    0.043843
# 48                  Vehicle_Leaving_Carriageway    0.032176
# 29                              Sex_of_Casualty    0.025877
# 23                          Urban_or_Rural_Area    0.023930
# 43                            Vehicle_Manoeuvre    0.022359
# 5                            Number_of_Vehicles    0.022333
# 13                                  Speed_limit    0.019320
# 26                          Vehicle_Reference_x    0.018030
# 42                      Towing_and_Articulation    0.014249
# 50                          1st_Point_of_Impact    0.013637
# 18                             Light_Conditions    0.013409
# 41                                 Vehicle_Type    0.013310

# %%
from sklearn.preprocessing import LabelBinarizer

cm = confusion_matrix(y_test, test_pred)
print("\nConfusion Matrix:\n", cm)

plt.figure(figsize=(6,4))
sns.heatmap(cm,annot=True,fmt="d",cmap='Blues',cbar=False,
            xticklabels=['Slight','Serious','Fatal']
            ,yticklabels=['Slight','Serious','Fatal'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# Full classification report
print("\nClassification Report:\n")
print(classification_report(y_test, test_pred,target_names=['Slight','Serious','Fatal'],zero_division=0))

y_pred_prob = model.predict_proba(X_test) # Get probabilities for all classes
roc_auc = roc_auc_score(y_test, y_pred_prob, multi_class='ovr', average='weighted')
print("ROC-AUC (weighted ovr):", roc_auc)

# ROC curve for each class
class_labels_str = ['Slight', 'Serious', 'Fatal']
lb = LabelBinarizer()
y_test_binarized = lb.fit_transform(y_test)
n_classes = y_test_binarized.shape[1]

plt.figure(figsize=(10, 8))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_binarized[:, i], y_pred_prob[:, i])
    roc_auc_per_class = roc_auc_score(y_test_binarized[:, i], y_pred_prob[:, i])
    plt.plot(fpr, tpr, label='ROC curve of class {} (area = {:.2f})'.format(class_labels_str[i], roc_auc_per_class))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (One-vs-Rest)')
plt.legend(loc="lower right")
plt.show()

# Calculate weighted average PR AUC manually
pr_auc_scores_per_class = []
for i in range(n_classes):
    pr_auc_scores_per_class.append(average_precision_score(y_test_binarized[:, i], y_pred_prob[:, i]))

class_counts = y_test_binarized.sum(axis=0)
pr_auc = np.average(pr_auc_scores_per_class, weights=class_counts)
print("PR AUC (weighted ovr):", pr_auc)

# Precision-Recall curve for each class
plt.figure(figsize=(10, 8))
for i in range(n_classes):
    precision_vals, recall_vals, _ = precision_recall_curve(y_test_binarized[:, i], y_pred_prob[:, i])
    pr_auc_score_per_class = average_precision_score(y_test_binarized[:, i], y_pred_prob[:, i]) # Recalculate or use from list
    plt.plot(recall_vals, precision_vals, label='PR curve of class {} (area = {:.2f})'.format(class_labels_str[i], pr_auc_score_per_class))

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (One-vs-Rest)')
plt.legend(loc="lower left")
plt.show()
# Out:
# Confusion Matrix:
#  [[  316   508   244]
#  [   53  6074  4813]
#  [   22  2011 40142]]
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       Slight       0.81      0.30      0.43      1068
#      Serious       0.71      0.56      0.62     10940
#        Fatal       0.89      0.95      0.92     42175
#
#     accuracy                           0.86     54183
#    macro avg       0.80      0.60      0.66     54183
# weighted avg       0.85      0.86      0.85     54183
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ROC-AUC (weighted ovr): 0.9201604139697842
# PR AUC (weighted ovr): 0.9192809482560508

# %%
import gradio as gr
import joblib
import pandas as pd

# %%
import joblib

joblib.dump(b_model, 'accident_model.pkl')
joblib.dump(X.columns, 'features.pkl')
joblib.dump(encoder, 'target_encoder.pkl')
# Out:
# ['target_encoder.pkl']

# %%
model = joblib.load('accident_model.pkl')
features = joblib.load('features.pkl')
target_encoder = joblib.load('target_encoder.pkl')

# %%
def predict_severity(*inputs):

    df_input = pd.DataFrame([inputs], columns=features)

    df_input['LSOA_of_Accident_Location'] = target_encoder.transform(df_input[['LSOA_of_Accident_Location']])

    prediction = model.predict(df_input)[0]

    severity_map = {1: "Slight", 2: "Serious", 3: "Fatal"}
    return severity_map.get(prediction, "Unknown")

# %%
inputs = [

    gr.Number(label="Casualty Type"),
    gr.Dropdown(choices=[1, 2], label="Police Attended? (1=Yes, 2=No)"),
    gr.Slider(1, 20, step=1, label="Number of Casualties"),
    gr.Number(label="Vehicle Leaving Carriageway"),
    gr.Dropdown(choices=[1, 2], label="Urban or Rural (1=Urban, 2=Rural)"),
    gr.Dropdown(choices=[1, 2], label="Sex of Casualty (1=Male, 2=Female)"),
    gr.Slider(1, 10, step=1, label="Number of Vehicles"),
    gr.Number(label="Vehicle Manoeuvre Code"),
    gr.Slider(10, 70, step=10, label="Speed Limit")
]

# %%
interface = gr.Interface(
    fn=predict_severity,
    inputs=inputs,
    outputs="text",
    title="UK Accident Severity Prediction System - 2018",
    description="Enter the accident details below to predict the severity level using the trained XGBoost model."
)

interface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://71f4439693f94194e6.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://71f4439693f94194e6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
df
# Out:
#         Location_Easting_OSGR  Location_Northing_OSGR  Longitude   Latitude  \
# 0                    534140.0                168370.0  -0.073120  51.398512
# 1                    534140.0                168370.0  -0.073120  51.398512
# 2                    535780.0                185300.0  -0.043058  51.550261
# 3                    534120.0                192440.0  -0.064263  51.614820
# 4                    529080.0                162590.0  -0.147913  51.347739
# ...                       ...                     ...        ...        ...
# 270936               319337.0                574511.0  -3.264352  55.058510
# 270937               319337.0                574511.0  -3.264352  55.058510
# 270938               319337.0                574511.0  -3.264352  55.058510
# 270939               318858.0                566932.0  -3.269695  54.990344
# 270940               316008.0                568771.0  -3.314764  55.006392
#
# ...
